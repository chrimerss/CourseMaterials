# %% [markdown]
# <figure>
#   <IMG SRC="https://raw.githubusercontent.com/mbakker7/exploratory_computing_with_python/master/tudelft_logo.png" WIDTH=250 ALIGN="right">
# </figure>
#
# # Principles of Geohydrology
# *Developed by Mark Bakker*

# %% [markdown]
# ### Introduction
# Groundwater is the most important resource of freshwater on earth.
# It moves very slowly through the top part of the earth's crust
# from areas of recharge (often originating from rainfall) to discharge in springs,
# wells, rivers, lakes, and oceans. The baseflow of
# rivers, the flow between rainfall or snowmelt events, is caused predominantly by inflow from
# groundwater. In many parts of the world, groundwater is the only source for drinking water or irrigation.
# Groundwater resources are threatened by over-exploitation and contamination.
# Major problems include a rapid decline of the groundwater table caused by pumping of groundwater for irrigated
# agriculture, salinization of groundwater resources due to heavy pumping in coastal areas, and contamination of
# groundwater by leakage of toxic chemicals. Accurate tools are needed to predict whether the current and
# proposed uses of groundwater resources are sustainable and safe.
#
# The field of groundwater flow, also called hydrogeology, is large and only the basic
# physical principles of groundwater flow through porous media are discussed in this Notebook. Detailed textbooks include
# Verruijt (1970), Bear (1972), Strack (2017), and Fitts (2012).
# This Notebook focuses on groundwater flow through porous materials such as
# sand, silt or clay. Significant amounts of groundwater may flow
# through fractured rock formations. The concepts outlined in this
# Notebook apply to such formations when the fractured rock may be
# represented by an equivalent porous medium.
#
# Compared to other areas of hydrology, the governing equations for
# groundwater flow are relatively well known. Exact solutions can be
# obtained for many important flow systems. These exact solutions
# provide important insights into the flow of groundwater and groundwater
# interactions with the accessible environment.

# %% [markdown]
# ### Very brief history
# The foundation of the quantitative description of groundwater flow
# was laid by Henry Darcy and Jules Dupuit. Darcy (1856) peformed
# column experiments that led to what is now called Darcy's law for
# groundwater flow. Jules Dupuit was a classmate of Darcy and his
# replacement as Director of Water and Bridges in Paris in the
# 1850s. Dupuit (1863) recognized that in many cases the vertical
# variation of the horizontal components of flow may be neglected,
# in essence reducing the mathematical description of groundwater
# flow by one dimension; one of his examples was a formula for flow
# to a well. At the end of the nineteenth century, Forchheimer
# (1886) combined Darcy's law with the continuity
# equation to show that steady groundwater flow through piecewise homogeneous aquifers is governed by
# Laplace's equation. This opened the door to many existing solutions that
# were derived for other problems governed by the same equation.
# Equations that describe transient groundwater flow take into
# account that the aquifer can store water. Phreatic storage,
# storage through movement of the groundwater table, was included by
# Boussinesq (1904). The process of elastic storage was
# conceptualized by Meinzer (1928), Theis (1935) and Jacob (1940)
# and led to the definition of storativity.

# %% [markdown]
# ### Hydraulic head
# The mechanical energy per unit weight in an incompressible fluid
# is given at a point by the following sum:
#
# $$
# \frac{p}{\gamma}+ Z + \frac{V^2}{2g}
# $$
#
# where $p$ [ML$^{-1}$T$^{-2}$] is pressure, $\gamma$
# [MT$^{-2}$L$^{-2}$] is the specific weight of the fluid, $Z$ [L] is
# the elevation above a fixed datum, $V$ [LT$^{-1}$] is the speed of
# the fluid, and $g$ [LT$^{-2}$] is the acceleration due to gravity.
# The first term, referred to as the pressure head, reflects the
# pressure energy of the fluid. The second term, referred to as the elevation head,  reflects the
# potential energy of the system. The third term, referred to as the velocity head, reflects the
# kinetic energy of the fluid.
#
# In groundwater applications, typical fluid speeds within the
# porous medium are so small that the velocity head is negligible.
# The combination of pressure head and elevation head is known as
# the hydraulic head, also called piezometric head or simply
# head. The dimension of head $h$ is length [L]:
#
# $$
# h=\frac{p}{\gamma}+ Z
# $$
#
# The hydraulic head provides a  good estimate of the available
# energy per unit weight at a point in a groundwater flow field, and
# is fairly easy to measure. The figure below shows a piezometer set into
# the saturated portion of an aquifer.  A piezometer is a hollow
# tube, open to the aquifer only at the bottom (point A in the
# figure). The hydraulic head at point A is the sum of the pressure head and elevation head. The fluid that rises into the
# piezometer is hydrostatic and the pressure at point A is
#
# $$
# p_A=\gamma H
# $$
#
# The pressure head at point A is $H$. The elevation head at
# point A, measured with respect to the datum shown in the figure, is
#  $L$. The hydraulic head at point A is  given by $L+H$ and is
# equal to the height above the datum to which water rises in the piezometer.
#
# <img src="gwfig1.png" width="450">
#
# **Figure 1.** Measurement of the hydraulic head at a point in an aquifer using a piezometer. Saturated zone
# is darker grey and is bounded on top by the groundwater table.
#
#
# The hydraulic head may be measured at a point in a
# groundwater flow field once a piezometer has been placed.
# Hydraulic head data at surface water features such as lakes and
# streams, which form the natural boundaries of many aquifers, are
# often available as time series. Head data is the most abundant
# information a groundwater engineer has at his disposal.

# %% [markdown]
# ### Darcy's law
# In 1856, Henry Darcy performed experiments from which he concluded
# that the flow of groundwater is proportional to the head gradient
# (Darcy, 1856). The general setup of the experiment is simple. A
# cylinder is filled with aquifer material. The ends of the cylinder
#  are attached to two reservoirs with different levels
# (see the figure below). Water flows through the aquifer material from the
# higher reservoir to the lower reservoir. In this fashion, Darcy
# showed  that the discharge $Q$ [L$^3$T$^{-1}$] through the soil
# column is proportional to the head difference $h_1-h_2$ [L] and
# the cross-sectional area $A$ [L$^2$] of the column, and inversely
# proportional to the length of the soil column $L$ [L]:
#
# $$
# Q = kA \frac{h_1-h_2}{L}
# $$
#
# The proportionality constant is $k$ [L/T] and is called
# the hydraulic conductivity. The equation above is
# adequate to describe flow through a soil column, but not flow
# through an aquifer. Flow through an aquifer is expressed in terms
# of the specific discharge vector $\vec{q}$ [LT$^{-1}$], the
# discharge per unit area of aquifer normal to the direction of flow:
#
# $$
# \vec{q}=-k \nabla h
# $$
#
# The components of $\vec{q}$ in the Cartesian $x$, $y$, and $z$
# directions may be written as
#
# $$
# q_x = -k\frac{\partial h}{\partial x} \qquad q_y = -k\frac{\partial h}{\partial y} \qquad q_z = -k\frac{\partial h}{\partial z}
# $$
#
# This equation is known as Darcy's law, although it is an
# empirical formula relating the head gradient to the specific
# discharge vector. Note the equivalence between Darcy's law and
# other physical laws such as Fourier's law for heat flux, Ohm's law
# for current density, and Fick's law for diffusive flux.
#
# <img src="gwfig2.png" width="400">
# **Figure 2.** The experiment of
# Darcy. Darcy used a vertical column, but the flow is independent of the angle of the soil column.
#
# The hydraulic conductivity of aquifers may be anisotropic.
# Sedimentary aquifers often consist of a sequence of thin layers of slightly
# coarser or slightly finer material. In such aquifers, the average vertical
# hydraulic conductivity is smaller than the average horizontal hydraulic
# conductivity. Hence, the hydraulic conductivity is anisotropic and
# is written as a tensor $\mathbf{K}$ so that Darcy's law becomes
#
# $$
# \vec{q} = -\mathbf{K} \nabla h
# $$
#
# When the principal directions of the hydraulic conductivity tensor
# coincide with the horizontal and vertical directions of
# sedimentary aquifers, the Cartesian components of Darcy's law
# become
#
# $$
# q_x = -k_h\frac{\partial h}{\partial x} \qquad q_y = -k_h\frac{\partial h}{\partial y} \qquad q_z = -k_v\frac{\partial h}{\partial z}
# $$
#
# where $k_h$ is the horizontal hydraulic conductivity and $k_z$ the
# vertical hydraulic conductivity.
#
# \begin{array}{|l|l|}
# \hline
# \text{Material} & \text{$k$ [m/day]} \\
# \hline
# \text{Clay} & <0.0001  \\
# \text{Sandy clays} & 0.0001-0.001 \\
# \text{Peat} & 0.0001-0.01 \\
# \text{Silt} & 0.001-0.01 \\
# \text{Very fine sands} & 0.1-1 \\
# \text{Fine sands} & 1-10 \\
# \text{Coarse sands} & 10-100 \\
# \text{Sands with gravel} & 100-1000 \\
# \text{Gravels} & >1000 \\
# \hline
# \end{array}
#
# **Table 1.** Hydraulic conductivity ranges for different aquifer materials.
#
# The hydraulic conductivity is a function of the fluid that flows
# through the aquifer and of the shapes, sizes and
# interconnectedness of the pores of the aquifer. For example, the
# hydraulic conductivity is smaller for oil than for water when flowing
# through the same aquifer, as oil is more viscous than water.
# Similarly, warmer water results in a larger hydraulic conductivity
# than colder water, as the viscosity of water decreases with
# temperature. The hydraulic conductivity may be written as
#
# $$
# k = \frac{\kappa \rho g}{\mu}
# $$
#
# where $\kappa$ [L$^2$] is called the intrinsic permeability of the
# aquifer and is a characteristic of the pore size distribution and tortuosity of the porous
# medium, $\rho$ [ML$^{-3}$] is the density of the fluid, $g$
# [LT$^{-2}$] is the acceleration of gravity, and $\mu$ [MLT$^{-1}$]
# is the dynamic viscosity. In this way the property of the porous
# material ($\kappa$) is separated from the properties of the fluid
# ($\rho$ and $\mu$). Variations of $\rho$ and $\mu$ may play a role in coastal aquifers because of changes in
# salinity, or in cases where the temperature of the groundwater varies significantly, for example
# in river bank filtration projects or systems for aquifer thermal energy storage.
#
# The hydraulic conductivity of an aquifer may be
# measured with a Darcy experiment. This requires, however, that
# undisturbed and representative samples are taken from an aquifer.
# As this is a difficult, if not impossible, task, field
# measurements are more likely to give accurate results.
# Representative values for the hydraulic conductivity are given in
# the table shown above for water flowing through different aquifer materials.
# The hydraulic conductivity generally varies spatially throughout an aquifer. The heterogeneity is rarely known well.
# The head and flow in the aquifer may often be simulated accurately by treating the aquifer
# properties as piecewise homogeneous. Travel times are, however, strongly affected by heterogeneity of the aquifer
# (e.g, Moore and Doherty, 2006).
#
# The specific discharge vector has the same units as a velocity and
# is sometimes called the Darcy flux or the Darcy velocity. These terms are confusing and are coonsidered bad terminology that should not be used. A water particle that flows
# through the aquifer does not flow with an average velocity equal
# to the specific discharge. The specific discharge is the discharge
# through a unit area of aquifer. Only part of this unit area
# consists of pores while the larger part consists of solid
# particles. The ratio of the volume of pores to the volume of
# solids is called the porosity $n$. Water can only flow through the
# pores, so that the average velocity vector $\vec{v}$ may be
# obtained from the specific discharge as
#
# $$
# \vec{v} = \vec{q}/n
# $$
#
# The velocity $\vec{v}$ is called an average velocity. The velocity through a larger
# pore, or through  the center of a pore is likely to be larger than
# the velocity through a smaller pore or along the edge of a soil
# particle.
#
# The average velocity of groundwater is generally very small. The
# head may drop 1 or 2 meters every 1000 meters. A gradient of 0.002
# in a sand with a hydraulic conductivity of 10 m/d and a porosity
# of 0.2 gives an average velocity of only 0.1 m/d. Larger velocities occur
# in very specific cases only, such as near pumping wells.

# %% [markdown]
# ### Steady conservation of mass
# Darcy's law provides three scalar equations for the four unknowns:
# $q_x$, $q_y$, $q_z$, and $h$. The fourth equation for solving the
# system is obtained from conservation of mass.
#
# A derivation of the differential statement of conservation of mass
# for a flowing fluid is given in any standard fluid mechanics text (e.g.,
# Munson et al., 2002). The result states that the divergence of the
# mass flow rate and the rate of accumulation of fluid mass are in
# balance at every point in the flow field
#
# $$\nabla\cdot(\rho \vec{v})+\frac{\partial\rho}{\partial t} = 0
# $$
#
# where $\vec{v}$ is the fluid velocity and $\rho$ the fluid
# density. By analogy, a statement for conservation of mass made for
# groundwater flowing through a porous material of porosity $n$ is
#
# $$
# \nabla\cdot(\rho \vec{q})+\frac{\partial(\rho n)}{\partial t} = 0
# $$
#
# The fluid density is multiplied by the porosity in the second term
# as the fluid mass occurs only in the pore spaces.  If the porous
# media is rigid ($\partial n/ \partial t = 0$) and the fluid density is constant in time, or if the flow is steady,
# the conservation of mass equation reduces to
#
# $$
# \nabla\cdot(\rho \vec{q})=0
# $$
#
# If, in addition, the fluid density is constant in space the simplest form of
# conservation of mass emerges
#
# $$
# \nabla\cdot\vec{q}=0
# $$
#
# This equation is also known as the continuity of flow equation; when the density
# is constant, conservation of mass is equivalent to continuity of flow.
# Conservation of mass may be combined with Dary's law
# to obtain a single  differential equation governing
# three-dimensional groundwater flow through a homogeneous aquifer
#
# $$
# \nabla^2 h = 0
# $$
#
# This result was first obtained by Forcheimer (1886) and this differential equation is known as Laplace's differential equation.

# %% [markdown]
# ### Flow Types
# Groundwater flow may be classified according to the spatial
# dimensions of the flow field, the dependence of the flow on time,
# and the aquifer setting in which the flow occurs. The focus in
# this Notebook (and other Notebooks that follow) is on one and two-dimensional, steady and transient
# flow in single aquifer systems with isotropic and homogeneous properties. These flow types and others are
# described below.
#
#
# #### Spatial Dimension
# Flow in an aquifer may be one-, two- or three-dimensional
# depending on the boundary conditions associated with the flow.
# Most aquifers are relatively thin in comparison to their areal
# extent. In these settings, which are referred to as shallow
# aquifers, one- and two-dimensional analyses are often adequate. In
# shallow aquifers the vertical variations in the hydraulic head are
#  negligibly small when compared to horizontal variations in
# head. For problems where three-dimensional flow is important, near
# local features such as partially penetrating or horizontal wells,
# or near partially penetrating streams, the effects of concentrated
# vertical flow can be incorporated approximately into
# two-dimensional models.
#
# #### Time Dependence
# Groundwater flow is either steady or transient.
# In steady flow, there are no changes in flow or head in
# time. Analyses of steady flow are used to reflect long-term,
# average conditions in an aquifer, for example the dewatering of an
# aquifer for a large construction project, or delineation of
# wellhead protection areas for municipal water supply wells.
# Transient flow occurs when aquifer boundary conditions change in
# time, for example, changing aquifer recharge, changing river
# levels, and varying pumping rates of wells. A specific application of a transient
# flow analysis is the evaluation of aquifer properties by field tests,
# such as pumping tests, when it is not practical to run the test
# until steady conditions are reached.
#
# #### Geologic Setting
# The geologic setting of an aquifer may be used to further define
# the flow-type as confined, unconfined, combined, or multi-aquifer
# flow. The subsoil may be divided in more permeable and less
# permeable layers.  The permeable layers may transmit significant
# amounts of water.  They are called aquifers and can be used as the
# source for drinking water or irrigation. The less permeable layers
# transmit little or no water and cannot be used for water supply;
# they are called aquicludes, confining layers, aquitards,
# or leaky layers.
#
# An aquifer is confined when it is bounded on the top and bottom by
# impermeable layers, or layers with significantly lower permeability than the aquifer. In contrast, an
# unconfined aquifer is not bounded on top by an impermeable layer.
# Flow in an aquifer is called confined when the head in the aquifer
# is above the impermeable top of the aquifer, as shown in the figure below.
#
# <img src="gwfig3.png" width="450">
# **Figure 3.** Definition of aquifer types and flow types. (a) Combined confined and unconfined flow, (b)
#   Unconfined flow with recharge.
#
# For unconfined flow, the saturated part of the aquifer is bounded
# on top by the groundwater table, also called the phreatic surface (see part b of the figure above).
# The concept of a groundwater table seems simple: when one digs a
# deep enough hole, it will fill up with water to the level of
# the groundwater table. Upon closer examination, the concept is
# less clear, however. When digging down, the soil gets wetter and
# wetter until the groundwater table is reached. In the section from
# the surface to the groundwater table, the pores of the soil are
# filled with both water and air; this section is called the
# unsaturated zone. The
# saturated zone starts at the phreatic surface, which is defined as
# the depth where the pressure in the water is equal to atmospheric.
# The phreatic surface is curved when there is flow in the aquifer. The surface goes down in the
# direction of flow, and thus the velocity of a water particle always has a
# downward component; in most cases this component is relatively
# small.
#
# In unconfined flow, the saturated thickness varies with the
# elevation of the water table.
# Flow in a confined aquifer becomes unconfined when the head
# falls below the impermeable top of the aquifer. In a
# confined aquifer, the flow may consist of both regions where the
# head is above the confining layer and regions where the head is
# below the confining layer.  This is referred to as combined
# confined and unconfined flow, or simply combined flow. Combined flow
# in a confined aquifer is illustrated in part a of the figure above.
#
# Often, aquifers are stratified with alternating layers of
# relatively permeable material separated by layers of less
# permeable materials.  The flow in these systems may move from one
# aquifer through a leaky layer to another aquifer, and is referred
# to as multi-aquifer flow.

# %% [markdown]
# ### The Dupuit approximation
# The basic idea behind the Dupuit approximation (also called the
# Dupuit-Forchheimer approximation), is to approximate groundwater flow
# in an aquifer as two-dimensional flow in a horizontal plane. The
# approximation allows many problems to be solved in simple form
# that otherwise could not be solved. Conditions of the Dupuit
# approximation are commonly stated as (e.g., Bear, 1972):
#
# 1. The flow is horizontal ($q_z=0$).
# 2. The hydraulic head is constant in the vertical ($h=h(x,y)$).
# 3. The hydraulic gradient is equal to the slope of the water table.
#
# There are various interpretations of the physical meaning of the
# Dupuit approximation.  Bear (1972) shows that the head predicted
# with a Dupuit model in a single aquifer represents the average
# head over the depth of the aquifer. Polubarinova-Kochina (1962)
# shows that Dupuit models are exact for anisotropic aquifers with
# infinite vertical hydraulic conductivity.  This idea was explored
# further by Kirkham (1967).
#
# Strack (1984) showed that conditions 2 and 3 listed above are
# consequences of neglecting the resistance to vertical flow in an
# aquifer, and that condition 1 is unnecessary. Strack's
# interpretation allows for the calculation of non-zero vertical
# flow components ($q_z$) and three-dimensional pathlines in
# two-dimensional Dupuit models of single- and multi-aquifer flow.
# Also, this interpretation clearly identifies where errors may be
# introduced by making the Dupuit approximation. Strack's
# interpretation is adopted here and **the Dupuit approximation is
# defined as neglecting the resistance to vertical flow in an
# aquifer.** As stated, the major advantage of the Dupuit approximation is a two-dimensional head field, $h=h(x,y)$, with
# two-dimensional horizontal flow components, $q_x=q_x(x,y)$ and
# $q_y=q_y(x,y)$.

# %% [markdown]
# ### Potential flow and the discharge vector
# The discharge vector, $\vec{Q}$, [L$^2$/T] is defined as the
# depth-integrated specific discharge vector. The discharge vector $\vec{Q}$ has two horizontal components $Q_x$ and $Q_y$. The $x$-component of
# the discharge vector is obtained as
#
# $$
# Q_x=\int_{Z_b}^{Z_t}q_x(x,y,z) dz
# $$
#
# where $Z_b$ and $Z_t$ are the bottom and top elevations of the
# saturated portion of the aquifer, respectively. Upon making the
# Dupuit approximation in a shallow aquifer, the discharge vector becomes
#
# $$
# Q_x=q_x(x,y)\int_{Z_b}^{Z_t}dz=q_x(Z_t-Z_b)
# $$
#
# The term in parenthesis is the saturated thickness of the aquifer. For confined flow, the saturated thickness
# equals the aquifer thickness $H$. For unconfined flow, it is equal to $h-Z_b$. In this Notebook, the datum for $h$ is chosen at the bottom of the aquifer ($Z_b=0$), so that the saturated
# aquifer thickness is $h$.
# Substituting Darcy's law into the equation for the discharge vector  and applying the appropriate saturated thicknesses gives
#
# $$
# Q_x=\begin{cases} q_xH =-kH\frac{\partial h}{\partial x}, &\text{confined flow} \\
# q_x h=-kh\frac{\partial h}{\partial x}, &\text{unconfined flow}\end{cases}
# $$
#
# The $y$-component of the discharge vector is obtained in a similar manner. The equation for the discharge vector suggests the existence of a
# discharge potential, $\Phi$ [L$^3$/T] (Strack, 1989)
#
# $$
# \Phi=\begin{cases} kHh-\frac{1}{2}kH^2, &\text{confined flow}\\
# \frac{1}{2}kh^2, &\text{unconfined flow}\end{cases}
# $$
#
# from which the discharge vector may be calculated as
#
# $$
# \vec{Q}=-\nabla\Phi
# $$
#
# When $h\ge H$, flow is confined, otherwise (or in absence of a confining layer) it is unconfined.
#
#
#
# The above equation for the potential represents a single potential for combined
# flow; the potential is continuous across the interface where flow
# changes from confined to unconfined and the head in the aquifer is
# equal to the aquifer thickness ($h=H$).  For confined flow, the
# product $kH$ is referred to as the transmissivity
# $T$ [L$^2$/T] of the aquifer.
#
# Groundwater flow may be written as potential flow when the base of
# the aquifer is horizontal and the aquifer properties are piecewise
# constant. Writing groundwater flow as potential flow simplifies
# the formulation of confined and unconfined flow and allows the use
# of the many potential flow solutions that exist in other fields.
# The definition of potential flow is that the flow is equal to the
# gradient of the potential. For groundwater flow, the definition is
# modified by adding a minus sign (the discharge vector is equal to minus the gradient of the potential).
# The discharge potential has no useful
# physical meaning, but is merely a convenient quantity in mathematical modeling.
#
# Using the discharge potential, Darcy's law has been rewritten in
# terms of the discharge vector.  The differential
# statement of conservation of mass may also be written in terms of
# the discharge vector. This may be done either by writing a flow
# balance on an elementary volume of aquifer (e.g., Strack, 2017),
# or by integrating the continuity equation over the depth of the
# aquifer (e.g., Bear, 1972). The result is
#
# $$
# \nabla\cdot\vec{Q}=N
# $$
#
# where $N$ [L/T] is the steady areal recharge rate, or the rate at
# which water infiltrates through the unsaturated zone into the
# saturated portion of the aquifer.  If the aquifer is confined, or
# there is no recharge to the aquifer, $N=0$.  Replacing the discharge vector
# in this equation by minus the gradient of the potential results in Poisson's equation
#
# $$
# \nabla^2\Phi=-N
# $$
#
# where the Laplacian is now understood to mean differentiation in
# the horizontal plane only. **Note that the beauty is that confined and unconfined flow are handled in the same way in terms of the discharge vector.** Boundary
# conditions are written in terms of $\Phi$ using the relationships between potential and head given above, in
# terms of components of $\vec{Q}$, or a combination of $\Phi$ and $\vec{Q}$. The resulting boundary-value
# problem is solved for $\Phi$ and the results translated to heads,
#  using the inverse of the relationship between potential and head.

# %% [markdown]
# ### One-dimensional flow
#
# For steady one-dimensional, confined,
# unconfined, or combined flow in a shallow aquifer, the governing Poisson's equation reduces to
#
# $$
# \frac{\text{d}^2 \Phi}{\text{dx}^2}=-N
# $$
#
# When the recharge rate $N$ is constant,
# the general solution to this differential equation is
#
# $$
# \Phi=-\frac{1}{2}Nx^2+Ax+B
# $$
#
# where $A$ and $B$ are constants that must be evaluated from
# boundary conditions. If the flow is confined, or there is no areal
# recharge, $N=0$. Three examples of one-dimensional flow that
# demonstrate various boundary conditions to evaluate the constants
# are presented below.

# %% [markdown]
# ### Confined flow between two rivers
# The simplest case of confined flow is one-dimensional flow between
# two fixed-head  boundaries, for example two fully penetrating
# rivers as illustrated in the figure below. When the aquifer is
# homogeneous, the solution shows that the head varies linearly
# between the head on the left and the head on the right.
#
# <img src="gwfig4.png" width="450">
#
# **Figure 4.** One-dimensional flow between two rivers. (a) confined flow, (b) combined
#   confined and unconfined flow.
#
# The head at the river to the left is equal to $h_L$ ($h_L\ge H$),
# and the head at the river to the right is $h_R$ ($h_R\ge H$). The
# boundary conditions are written in terms of the discharge
# potential:
#
# $$
# \Phi_L=\Phi(x=0)=kHh_L-\frac{1}{2}kH^2\qquad
# \Phi_R=\Phi(x=L)=kHh_R-\frac{1}{2}kH^2
# $$
#
# Application of the boundary conditions to the general solution
# with $N=0$ results in the following discharge potential
#
# $$
# \Phi=-\frac{\Phi_L-\Phi_R}{L} x +\Phi_L
# $$
#
# The discharge vector is obtained by differentiating the potential and adding a minus sign
#
# $$
# Q_x=-\frac{\text{d}\Phi}{\text{d}x}=\frac{\Phi_L-\Phi_R}{L}
# $$
#
# $Q_x$ is constant throughout the aquifer.  Alternatively the
# discharge potential may be written as
#
# $$
# \Phi=-Q_x x+\Phi_L
# $$

# %% [markdown]
# #### Example 1
# Consider the case that $H=20$ m, $k=10$ m/d, $L=1000$ m, $h_L=31$ m, and $h_R=29$ m.
# In the code below, the discharge between the two rivers (per meter length of river) is computed and the head between the two rivers is plotted.

# %%
from pylab import *
# %matplotlib inline

H = 20
k = 10
L = 1000
hL = 31
hR = 29
PhiL = k * H * hL - 0.5 * k * H ** 2
PhiR = k * H * hR - 0.5 * k * H ** 2
PhiL2 = k * H * hL
PhiR2 = k * H * hR
Qx = (PhiL - PhiR) / L
Qx2 = (PhiL2 - PhiR2) / L
x = linspace(0, L, 100)
Phi = -Qx * x + PhiL
Phi2 = -Qx2 * x + PhiL2
h = (Phi + 0.5 * k * H ** 2) / (k * H)
h2 = (Phi2 + 0.5 * k * H ** 2) / (k * H)
plot(x, h,color='b')
plot(x, h2, color='r')

xlabel('x (m)')
ylabel('head (m)')
title('Qx equals:' + str(round(Qx, 3)) + 'm$^2$/day');

# %% [markdown]
# #### Combined flow between two rivers
# If the head at the river on the right is below the aquifer
# confining unit ($h_R<H$), the flow in the aquifer will be combined
# flow. In this case, $\Phi_R$ is computed as
#
# $$
# \Phi_R=\frac{1}{2}kh_R^2
# $$
#
# The head at the left remains above the confining unit, and
# therefore $\Phi_L$ is defined as before.
#
# The solution of the discharge potential as a function of $x$, as given above,
# is still valid, as well as the expression for
# $Q_x$. The location $x_c$ where the flow changes from
# confined to unconfined flow, as shown in Figure b above, is found by
# setting the discharge potential equal to $kH^2/2$ and solving for
# the $x$-coordinate
#
# $$
# x_c=\frac{\Phi_L-kH^2/2}{Q_x}
# $$

# %% [markdown]
# #### Example 2
# Consider the case that $H=20$ m, $k=10$ m/d, $L=1000$ m, $h_L=21$ m, and $h_R=19$ m.
# In the code below, the discharge between the two rivers (per meter length of river) is computed and the head between the two rivers is plotted. Note that the answer is almost the same as for confined flow, as the saturated thickness changes only a little bit (gradually from 20 to 19 over approximately half the distance).

# %%
from pylab import *
# %matplotlib inline

H = 20
k = 10
L = 1000
hL = 21
hR = 19
PhiL = k * H * hL - 0.5 * k * H ** 2
PhiR = 0.5 * k * hR ** 2
Qx = (PhiL - PhiR) / L
x = linspace(0, L, 100)
Phi = -Qx * x + PhiL
Phic = 0.5 * k * H ** 2
h = zeros_like(Phi)
h[Phi >= Phic] = (Phi[Phi >= Phic] + 0.5 * k * H ** 2) / (k * H)  # same as before
h[Phi < Phic] = sqrt(2 * Phi[Phi < Phic] / k)
plot(x, h)
xlabel('x (m)')
ylabel('head (m)')
title('Qx equals:' + str(round(Qx, 3)) + 'm$^2$/day');

# %% [markdown]
# #### Unconfined flow in a river valley
# Consider unconfined flow in a buried bedrock valley to
# a river of constant head, illustrated in the figure below.   There is no
# confining unit on the aquifer.
# The right aquifer boundary ($x=L$) is the impermeable valley wall
# and the left boundary ($x=0$) is the river. The corresponding
# boundary conditions are
#
# $$
# Q_x(x=L)=0
# $$
#
# $$
# \Phi(x=0)=\frac{1}{2}kh_L^2=\Phi_L
# $$
#
# Application of the boundary conditions to the general solution results in
#
# $$
# \Phi=-Nx\left(\frac{x}{2}-L\right) +\Phi_L
# $$
#
# <img src="gwfig5.png" width="450">
# **Figure 5.** One-dimensional unconfined flow in a river valley with recharge.

# %% [markdown]
# #### Example 3
# Consider the case that $k=10$ m/d, $L=2000$ m, $h_L=20$ m, and $N=1$ mm/d.
# In the code below, the head is plotted as a function of $x$ and the head at the buried bedrock valley is added as a title to the graph.

# %%
k = 10
L = 2000
hL = 20
N = 0.001
x = linspace(0, L, 100)
PhiL = 0.5 * k * hL ** 2
Phi = -N * x * (x / 2 - L) + PhiL
h = sqrt(2 * Phi / k)
plot(x, h)
xlabel('x (m)')
ylabel('head (m)')
title('head at bedrock valley:' + str(round(h[-1], 2)) + ' m');

# %% [markdown]
# ### Exercise 1
# For Example 1 and 2, compute the discharge from the left river to the right river for the following two cases with the same total head drop.
#
# a) $h_L=32$ m, $h_R=22$ m
#
# b) $h_L=22$ m, $h_R=12$ m (this is a significant reduction in the saturated thickness)
#
# Use that $k=10$ m/d, $L=5000$ m, $H=20$ m for both cases.

# %% [markdown]
# H=20H=20  m,  k=10k=10  m/d,  L=1000L=1000  m

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
H, k, L, hL, hR = 20, 10, 1000, 32, 22
phi0 = k*hL*H - 1/2*k*H**2
phi1 = k*hR*H - 1/2*k*H**2
x= np.linspace(0, L, 1000)
phi= phi0 + (phi1-phi0)/L*x
Q= -(phi1-phi0)/L
h= phi/ k/ H
plt.figure()
plt.plot(x, h)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### Exercise 2
# For Example 3, derive and plot an expression for $Q_x(x)$, compute the discharge $Q_x(x=0)$ into the river and compare it to the discharge you can compute from continuity of flow.

# %% [markdown]
# Consider the case that  k=10k=10  m/d,  L=2000L=2000  m,  hL=20hL=20  m, and  N=1N=1  mm/d. In the code below, the head is plotted as a function of  xx  and the head at the buried bedrock valley is added as a title to the graph.

# %%
# 2 boundary conditions 
# one is at left boundary h=h_L
# At right side, Q_x=0 because of impermeable flow
k, L, h1, N = 10, 2000, 20, 1*10**(-3)
phiL= 1/2 * h1**2 * k
x= np.linspace(0,L,5000)
Q = N*(x-L)
plt.figure()
plt.plot(x,Q)
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show>

# %% [markdown]
# ### Exercise 3
# A geohydrologist wants to measure the porosity and hydraulic conductivity in the field using a bucket. The bucket has a height of 50 cm and a diameter of 30 cm, and is approximately a cylinder. He fills the bucket with 40 cm of dry sand. Next, he measures how much water he needs to add to the bucket such that the water level in the bucket is exactly at the top of the sand; this turns out to be 10 liters.
# Question:
#
# a) What is the porosity of the sand?
#
# Next, the gohydrologist punches a bunch of holes in the bottom of the bucket and fills it again with 40 cm of dry sand. He proceeds to fill the bucket until the water level is exactly at the top of the bucket. He keeps adding water to the bucket so that the water level remains at the top of the bucket while water flows out of the bucket through the holes in the bottom. Once the situation has become stationary, the hydrogeologist measures that one liter of water flows out of the bottom of the bucket in one minute. Heads are measured with respect to the bottom of the bucket.
# Questions:
#
# b) What are the elevation head, pressure head, and hydraulic head at the top of the sand?
#
# c) What are the elevation head, pressure head, and hydraulic head at the bottom of the sand?
#
# d) What is the hydraulic conductivity of the sand in m/day?
#
# e) How long does it take for a water particle to travel from the top of the sand to the bottom of the sand. Give your answer in minutes.

# %%
A = 0.3**2*pi*0.5*0.5
H = 0.5
print ("The porosity is %s percent"%((10**(-2)-0.1*A)/A*H*100))
# Out:
# The porosity is 2.0735530263064588 percent

# %% [markdown]
# ### Exercise 4
#
# Consider groundwater flow between two long parallel rivers. The water level in the left river is $h_1$ and in the right river $h_2$, measured with respect to the bottom of the aquifer. The distance between the two rivers is $L$. Between the rivers, vegetation transpires more water than precipitation. The net areal evaporation from groundwater is $E$. The hydraulic conductivity of the aquifer is $k$.
# Given: $h_1=10$ m, $h_2=9$ m, $L=1000$ m, $E=0.5$ mm/d, $k=5$ m/d.
# Approximate the saturated thickness of the aquifer as $D = (h_1 + h_2)/2$.
#
# Questions:
#
# a) Derive an equation for the head as a function of $x$ between the two rivers and compute the head halfway the rivers.
#
# b) Derive an equation for the discharge vector as a function of $x$.
#
# c) Compute how much water flows from the left river into the aquifer (negative when water flows from the aquifer into the river).
#
# d) Compute how much water flows from the right river into the aquifer (negative when water flows from the aquifer into the river).
#
# e) Find the point in the aquifer between the two rivers where the flow is equal to zero.
#
# f) Plot the head as a function of $x$.

# %%
h1, h2, L, E, k = 10, 9, 1000, 0.5*10**(-3), 5
D = (h1+h2)/2
def phi(x):
    phi = -1/2*E*x**2+(1/2*k*h2**2+1/2*E*L**2-k*D*h1+1/2*k*D**2)/L*x +k*D*h1-1/2*k*H**2
    return phi
from scipy.optimize import fsolve
x = fsolve(phi,200)
x
# Out:
# F:\Anaconda\lib\site-packages\scipy\optimize\minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# array([ 408.03754755])

# %%
x_c
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-bad3d399ebe1> in <module>()
# ----> 1 x_c[1]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %% [markdown]
# ### References
# Bear J (1972) Dynamics of Fluids in Porous Media. Dover Publications, New York, USA.
# Boussinesq J (1904) Recherches thoretique sur l’coulement des nappes d’eau infiltres dans le sol et sur le dbit des sources. J. Math. Pure Appl. 10: 363-394.
# Darcy H (1856) Les Fourntaines Publiques de la Vlle de Dijon. Dalmont, Paris.
# Dupuit J (1863) Études Théoriques et Practiques sur le Mouvement des Eaux dans les Canaux Decouverts et á Travers les Terrains Perméables. 2nd ed. Dunod, Paris, France.
# Fitts CR (2012) Groundwater Science, 2nd Edition. Academic Press, New York, USA.
# Forchheimer P (1886) Ueber die Egiebigkeit von Brunnenanlagen und Sickerschlitzen. Z. Architekt. Ing. Ver. Hannover 32: 539-563.
# Jacob CE (1940) The flow of water in an elastic artesian aquifer. Trans. Am. Geophys. Un. 21: 574-586.
# Kirkham, D (1967), Explanation of paradoxes in Dupuit-Forchheimer seepage theory. Water Resources Research 3(2): 609-622.
# Meinzer OE (1928) Compressibility and elasticity of artesian aquifers. Economic Geology 23: 263-291.
# Moore C, Doherty J (2006) The cost of uniqueness in groundwater model calibration. Advances in Water Resources 29: 605-623.
# Munson BR, Young DF and Okiishi TH (2002) Fundamentals of Fluid Mechanics, Fourth Edition, John Wiley and Sons, New York.
# Polubarinova-Kochina PY (1962) Theory of Groundwater Movement (translated by JMR De Wiest). Princeton University Press, Princeton, NJ.
# Strack ODL (1984) Three-dimensional streamlines in Dupuit-Forchheimer models, Water Resour Res., 20(7), 812-822.
# Strack ODL (2017) Analytical Groundwater Mechanics. Cambridge University Press, Cambridge, UK.
# Theis CV (1935) The relation between the lowering of the piezometric surface and the rate and duration of discharge of a well using ground-water storage. Trans Amer Geophys Union 16: 519524.
# Verruijt A (1970) Theory of Groundwater Flow. MacMillan, New York, USA.

# %% [markdown]
# **Note:** This Notebook is adapted from a document that is published as M Bakker and EI Anderson. 2011. Mechanics of Groundwater Flow. In: *Treatise on Water Science*, vol. 2, edited by P Wilderer, Academic Press, Oxford, 115-134.
